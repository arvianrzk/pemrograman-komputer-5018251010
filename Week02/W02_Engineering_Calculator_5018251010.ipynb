# %% [markdown]
# <a href="https://colab.research.google.com/github/arvianrzk/pemrograman-komputer-5018251010/blob/main/Week02/W02_Engineering_Calculator_5018251010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 Assignment
# ## Engineering Unit and Electrical Calculator
# Nama: Arkana Rizky Faviansyah
# NRP: 5018251010
# Kelas: Pemrograman Komputer

# %% [markdown]
# ##Task 1: Speed Unit Conversion
#
#
# ---
#
#
# Buat program yang menerima masukan kecepatan dalam km/h, kemudian mengubahnya menjadi
# m/s. gunakan persamaan: ![image.png](data:image/png;base64,...)

# %%
speed_kmh = float(input("Enter speed [km/h]: "))
speed_ms = speed_kmh / 3.6
print(f"Speed: {speed_ms:.2f} m/s")
# Out:
# Enter speed [km/h]: 10
# Speed: 2.78 m/s

# %% [markdown]
# ##Task 2: Power Unit Conversion
#
#
# ---
#
#
# Buat program untuk mengubah daya dari kW menjadi W.
# gunakan persamaan: Pw = 1000PkW

# %%
power_kw = float(input("Power [kW]: "))
power_w = power_kw * 1000
print(f"Power: {power_w:.2f} W")
# Out:
# Power [kW]: 12.5
# Power: 12500.00 W

# %% [markdown]
# ##Task 3: Electrical Power and Energy Calculator
#
#
# ---
#
#
# Buat program yang meminta pengguna memasukkan:
# • tegangan dalam V;
# • arus dalam A;
# • waktu operasi dalam jam.
# Hitung daya:
# P = V I
# dan energi:
# E = P = 1000PkW

# %%
voltage = float(input("Enter voltage [V]: "))
current = float(input("Enter current [A]: "))
operating_time = float(input("Enter operating time [hours]: "))

power = voltage * current
energy = power * operating_time

print("\n===== ELECTRICAL CALCULATION =====")
print(f"Voltage        = {voltage:.2f} V")
print(f"Current        = {current:.2f} A")
print(f"Power          = {power:.2f} W")
print(f"Operating Time = {operating_time:.2f} hour")
print(f"Energy         = {energy:.2f} Wh")
# Out:
# Enter voltage [V]: 24
# Enter current [A]: 8.5
# Enter operating time [hours]: 3
#
# ===== ELECTRICAL CALCULATION =====
# Voltage        = 24.00 V
# Current        = 8.50 A
# Power          = 204.00 W
# Operating Time = 3.00 hour
# Energy         = 612.00 Wh

# %% [markdown]
# ##Task 4: Comparison and Logical Operators
#
#
# ---
#
#
# Gunakan hasil Task 3 untuk membuat beberapa nilai Boolean.
# Gunakan batas berikut: power_limit = 200
# voltage_limit = 24 Buat variabel:
# is_high_power = power > power_limit
# is_high_voltage = voltage > voltage_limit
# Catatan: pada tugas ini mahasiswa belum perlu menggunakan if, karena materi percabangan
# dibahas pada Minggu 3

# %%
power_limit = 200
voltage_limit = 24

is_high_power = power > power_limit
is_high_voltage = voltage > voltage_limit

print(f"High power: {is_high_power}")
print(f"High voltage: {is_high_voltage}")
print(f"Both conditions: {is_high_power and is_high_voltage}")
print(f"Any condition: {is_high_power or is_high_voltage}")
# Out:
# High power: True
# High voltage: False
# Both conditions: False
# Any condition: True

# %% [markdown]
# ##Test Cases
# Program wajib diuji menggunakan minimal tiga test case berikut:
# | Test Case | Voltage [V] | Current [A] | Time [h] |
# | :--- | :---: | :---: | ---: |
# | Test 1 | 12 | 5.0 | 2.0 |
# | Test 2 | 24 | 8.5 | 3.0 |
# | Test 3 | 48 | 10.0 | 1.5 |
#
#
# Mahasiswa boleh menambahkan test case lain. Semua output hasil pengujian harus tetap
# tersimpan di notebook.

# %%
voltage = float(input("Enter voltage [V]: "))
current = float(input("Enter current [A]: "))
operating_time = float(input("Enter operating time [hours]: "))

power = voltage * current
energy = power * operating_time

print("\n===== ELECTRICAL CALCULATION =====")
print(f"Voltage        = {voltage:.2f} V")
print(f"Current        = {current:.2f} A")
print(f"Power          = {power:.2f} W")
print(f"Operating Time = {operating_time:.2f} hour")
print(f"Energy         = {energy:.2f} Wh")
# Out:
# Enter voltage [V]: 12
# Enter current [A]: 5
# Enter operating time [hours]: 2
#
# ===== ELECTRICAL CALCULATION =====
# Voltage        = 12.00 V
# Current        = 5.00 A
# Power          = 60.00 W
# Operating Time = 2.00 hour
# Energy         = 120.00 Wh

# %%
voltage = float(input("Enter voltage [V]: "))
current = float(input("Enter current [A]: "))
operating_time = float(input("Enter operating time [hours]: "))

power = voltage * current
energy = power * operating_time

print("\n===== ELECTRICAL CALCULATION =====")
print(f"Voltage        = {voltage:.2f} V")
print(f"Current        = {current:.2f} A")
print(f"Power          = {power:.2f} W")
print(f"Operating Time = {operating_time:.2f} hour")
print(f"Energy         = {energy:.2f} Wh")
# Out:
# Enter voltage [V]: 24
# Enter current [A]: 8.5
# Enter operating time [hours]: 3
#
# ===== ELECTRICAL CALCULATION =====
# Voltage        = 24.00 V
# Current        = 8.50 A
# Power          = 204.00 W
# Operating Time = 3.00 hour
# Energy         = 612.00 Wh

# %%
voltage = float(input("Enter voltage [V]: "))
current = float(input("Enter current [A]: "))
operating_time = float(input("Enter operating time [hours]: "))

power = voltage * current
energy = power * operating_time

print("\n===== ELECTRICAL CALCULATION =====")
print(f"Voltage        = {voltage:.2f} V")
print(f"Current        = {current:.2f} A")
print(f"Power          = {power:.2f} W")
print(f"Operating Time = {operating_time:.2f} hour")
print(f"Energy         = {energy:.2f} Wh")
# Out:
# Enter voltage [V]: 48
# Enter current [A]: 10
# Enter operating time [hours]: 1.5
#
# ===== ELECTRICAL CALCULATION =====
# Voltage        = 48.00 V
# Current        = 10.00 A
# Power          = 480.00 W
# Operating Time = 1.50 hour
# Energy         = 720.00 Wh

# %% [markdown]
# ## Short Reflection
#
# ---
#
#
#
# 1.   int adalah tipe data bilangan bulat, sedangkan float adalah tipe data bilangan desimal.
# 2.   int adalah tipe data bilangan bulat, sedangkan float adalah tipe data bilangan desimal.
# 3.   = adalah operator assignment (penetapan nilai ke variabel), sedangkan == adalah operator perbandingan (memeriksa kesamaan dua nilai).
# 4.   Operator and bernilai True jika kedua kondisi benar, sedangkan or bernilai True jika salah satu kondisi benar.
# 5.   Perbedaan penulisan variabel pada proses dan ketika output / mengakibatkan nilai eror karena variabel salah tulis belum di panggil di program
